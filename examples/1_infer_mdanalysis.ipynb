# %% [markdown]
# # Batch Inference Helper
#
# This notebook demonstrates `geom2vec.data.infer_mdanalysis_folder`, a high-level wrapper
# that extracts trajectories with MDAnalysis and runs inference only for files that
# have not been processed yet. Configure the topology/trajectory paths below and run
# each cell in order.

# %%
from pathlib import Path

import torch

from geom2vec import create_model_from_checkpoint, infer_checkpoint_config
from geom2vec.data import infer_mdanalysis_folder
# Out:
# /project/dinner/zpengmei/conda_envs/openmm/lib/python3.12/site-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /lib64/libm.so.6: version `GLIBC_2.29' not found (required by /project/dinner/zpengmei/conda_envs/openmm/lib/python3.12/site-packages/libpyg.so)
#   import torch_geometric.typing
# /project/dinner/zpengmei/conda_envs/openmm/lib/python3.12/site-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /lib64/libm.so.6: version `GLIBC_2.29' not found (required by /project/dinner/zpengmei/conda_envs/openmm/lib/python3.12/site-packages/libpyg.so)
#   import torch_geometric.typing

# %%
# Update these paths for your system
topology_file = (
    "/project/dinner/anton_trajs/Chignolin/DESRES-Trajectory_CLN025-0-protein/CLN025-0-protein/chignolin.pdb"
)
trajectory_folder = (
    "/project/dinner/anton_trajs/Chignolin/DESRES-Trajectory_CLN025-0-protein/CLN025-0-protein/"
)
output_dir = Path("/project/dinner/zpengmei/geom2vec_02/examples/_artifacts/chignolin_infer")
output_dir.mkdir(parents=True, exist_ok=True)

stride = 10  # increase for faster prototyping
selection = "prop mass > 1.1"  # focus on heavy atoms

# %%
checkpoint_path = Path("/project/dinner/zpengmei/apps/geom2vec/checkpoints/visnet_l6_h256_rbf32_r5_pcqm.pth")
device = "cuda" if torch.cuda.is_available() else "cpu"

# config = infer_checkpoint_config(str(checkpoint_path))
# config

rep_model = create_model_from_checkpoint(
    checkpoint_path=str(checkpoint_path),
    device=device,
)
# Out:
# /project/dinner/zpengmei/apps/geom2vec/src/geom2vec/models/factory.py:79: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# Model loaded from /project/dinner/zpengmei/apps/geom2vec/checkpoints/visnet_l6_h256_rbf32_r5_pcqm.pth

# %%
summary = infer_mdanalysis_folder(
    model=rep_model,
    topology_file=topology_file,
    trajectory_folder=trajectory_folder,
    output_dir=str(output_dir),
    stride=stride,
    selection=selection,
    batch_size=100,
    reduction="sum",
    overwrite=True,
)
# Out:
# Inference:   0%|          | 0/54 [00:00<?, ?it/s]
# /project/dinner/zpengmei/conda_envs/openmm/lib/python3.12/site-packages/MDAnalysis/coordinates/DCD.py:171: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
